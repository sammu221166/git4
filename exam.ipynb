# %% [markdown]
# <a href="https://colab.research.google.com/github/sammu221166/git4/blob/main/exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/tips13.csv')
df
df.info()
df.describe()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        238 non-null    float64
#  1   tip               238 non-null    float64
#  2   sex               233 non-null    object
#  3   smoker            236 non-null    object
#  4   day               228 non-null    object
#  5   time              235 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  240 non-null    float64
#  8   Payer Name        236 non-null    object
#  9   CC Number         236 non-null    float64
#  10  Payment ID        239 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.1+ KB
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# ...

# %%
df.isnull().sum()
# Out:
# total_bill           6
# tip                  6
# sex                 11
# smoker               8
# day                 16
# time                 9
# size                 0
# price_per_person     4
# Payer Name           8
# CC Number            8
# Payment ID           5
# dtype: int64

# %%
new_df=df.fillna(0)
new_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01       0     No     0       0     2              8.49
# 1          0.00  1.66       0      0   Sun  Dinner     3              3.45
# 2          0.00  3.50    Male      0     0       0     3              7.00
# 3         23.68  3.31       0     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female      0   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/tips13.csv')
plt.scatter(df['total_bill'],df['tip'])
plt.title('scatter plot')
plt.xlabel('total bill')
plt.ylabel('tips')
plt.show()
